# %% [markdown]
# # Vertical Profiles
#
# In this example, we will plot the following:
#
# 1) Current vertical profiles for Temperature/Relative Humidity/Wind for Brisbane, Austrailia.
# 2) Relative Humidity and Wind Comparison 10/30/2023 00z vs 10/29/2023 00z - Visualize Santa Ana Winds
#
# [Documentation](https://github.com/edrewitz/firewxpy/blob/main/Documentation/firewxpy%202.0/vertical%20profiles.md#observed-vertical-profiles)

# %% [markdown]
# ## Imports

# %%
from firewxpy import observed_vertical_profiles

# %% [markdown]
# For the list of upper-air site codes - [Click Here](http://www.weather.uwyo.edu/upperair/naconf.html)

# %% [markdown]
# #### Brisbane Airport

# %% [markdown]
# [Click here](http://www.weather.uwyo.edu/upperair/naconf.html) for the list of station codes.

# %%
observed_vertical_profiles.plot_temperature_relative_humidity_wind_profile('YBBN')
# Out:
# Saved YBBN.png profiles to FireWxPy Graphics/Observations/Upper Air/Temperature Relative Humidity Wind Profiles.

# %% [markdown]
# ![image](https://github.com/edrewitz/firewxpy/blob/main/Example%20Graphics/YBBN.png?raw=true)

# %% [markdown]
# ### San Diego Santa Ana Winds

# %%
observed_vertical_profiles.plot_relative_humidity_wind_profile_comparison('nkx',
                                                                          current=False,
                                                                          custom_time_1='2023-10-30:00', 
                                                                          custom_time_2='2023-10-29:00',
                                                                          rh_color='darkorange',
                                                                          rh_comp_color='green',
                                                                          wind_color='red')
# Out:
# Saved NKX.png profiles to FireWxPy Graphics/Observations/Upper Air/Relative Humidity Wind Profiles Comparison.

# %% [markdown]
# ![image](https://github.com/edrewitz/firewxpy/blob/main/Example%20Graphics/santa_ana_winds.png?raw=true)
