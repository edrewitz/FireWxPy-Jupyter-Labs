# %%
'''
In this example, we will create the ERC charts for South Ops using the data from FEMS

First, let's begin with our import!
'''
from firewxpy import create_psa_erc_fuels_charts

# %%
'''
Next, let's call our function. In this case, let's use our standard Fuel Model Y. 

We will base our climatology starting from January 1st, 2009. 

OSCC is the formal abbreviation for South Ops

Now let's make our plots!
'''
create_psa_erc_fuels_charts('oscc', start_date='2009-01-01')
# Out:
# ERC Fuels Charts Saved To f:Fuels Maps/OSCC/ERC
