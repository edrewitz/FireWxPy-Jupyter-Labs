# %%
'''
In this example, we will plot the NWS Maximum RH Forecast across the state of Texas. 

First let's start with our imports
'''
from firewxpy import nws_relative_humidity_forecast as rh

# %%
'''
Now let's make out graphics. Since we are only creating one set, we can download the data inside of the function

We need to also set state='tx'
'''

rh.plot_maximum_relative_humidity_forecast(state='tx')
# Out:
# Retrieved ds.maxrh.bin NDFD grids.
# Saved short-term forecast graphics to f:Weather Data/NWS Forecasts/MAXIMUM RH LOW CONTOUR 30% HIGH CONTOUR 80%/TX/States & Counties
# Saved extended forecast graphics to f:Weather Data/NWS Forecasts/MAXIMUM RH LOW CONTOUR 30% HIGH CONTOUR 80%/TX/States & Counties
