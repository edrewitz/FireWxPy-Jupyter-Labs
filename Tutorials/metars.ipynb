# %%
'''
In this example, we will make a plot of METAR Observations across CONUS

Let's start with our imports:
'''
from firewxpy import metar_obs

# %%
'''
We don't need to change any of the optional arguments in this case since we are using default and are downloading
the data inside of the function.

Now let's make our plot!
'''
metar_obs.plot_observations_map()
# Out:
# Saved METAR Map.png to f:Weather Data/Observations/METAR MAP/CONUS/States & Counties
