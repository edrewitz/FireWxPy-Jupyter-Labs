# %%
'''
In this example, I will demonstrate a first time set-up of FireWxPy. We will show you that when running FireWxPy for the first time, all the shapefiles download and install automatically.
This is only done during a first time user set-up as when the shapefiles are already installed, we don't need to install them again. 
You will also see that FireWxPy builds the directory and new branches of the directory for where the graphics are saved to. 

In this example, we will make a basic plot of the Real Time Mesoscale Analysis Data for my homestate of California. 
We will look at the RTMA for Relative Humidity. 

Now we need to import our RTMA module. You will see the print statements showing you everything is being set up properly on this first-time execution. 
'''
from firewxpy import rtma
# Out:
# Welcome First Time FireWxPy User!
# Let me set you up automatically by downloading & installing all the shapefiles while also building the Weather Data directory for you.
# My Motto is: 'Let the FireWxPy functions do the work so you don't have to!'
# Setting Up...
# Set Up Complete! Have Fun!

# %%
'''
Now we will make our plot. In this example, we will download the data inside of the function since we are only making one graphic. 
If you want to make a bunch of different graphics off the same dataset, it is recommended to download the data outside of the function
and pass it in to limit data requests on the server that houses the data. Please see the RTMA Alaska example for this where we will 
make graphics for the entire state and all the NWS CWAs in Alaska Region.
'''

rtma.plot_relative_humidity(state='ca')
# Out:
# Built f:Weather Data
# Built f:Weather Data/RTMA
# Built f:Weather Data/RTMA/RTMA RH WITHOUT CONTOUR THRESHOLDS
#  Built f:Weather Data/RTMA/RTMA RH WITHOUT CONTOUR THRESHOLDS/CA
# Built f:Weather Data/RTMA/RTMA RH WITHOUT CONTOUR THRESHOLDS/CA/States & Counties
# There is no data for 03/24/2025 18Z trying to retrieve data from the previous analysis at 03/24/2025 18Z
# Data was successfully retrieved for 03/24/2025 18Z
# Data was successfully retrieved for 03/23/2025 18Z
# Saved RTMA RH graphic to f:Weather Data/RTMA/RTMA RH WITHOUT CONTOUR THRESHOLDS/CA/States & Counties
