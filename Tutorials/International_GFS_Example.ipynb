# %%
'''
In this example, we will create GFS 0.25x0.25 degree forecast 700mb height/relative humidity/wind across Central & Eastern Europe

Please see the documentation page for more information regarding international abbreviations

Let's begin with our imports!
'''
from firewxpy import model_relative_humidity as relative_humidity

# %%
'''
Now, let's call our function. Since we are only making one series of plots, we can just download the data inside of the function.

We will need to define that we are using the GFS0p25 and we want to look at Central & Eastern Europe

Now let's make our plots!
'''
relative_humidity.plot_heights_relative_humidity_wind('GFS0p25', 'Central & Eastern Europe')
# Out:
# 18z run not available yet. Now trying the 12z run.
# 12z run downloaded successfully!
# f:Forecast Model Data/GFS0P25/CENTRAL & EASTERN EUROPE Directory does not exists.
# Building new branches automatically...
# Successfully built f:Forecast Model Data/GFS0P25/CENTRAL & EASTERN EUROPE Branch.
# Successfully built f:Forecast Model Data/GFS0P25/CENTRAL & EASTERN EUROPE/STATES ONLY Directory.
# f:Forecast Model Data/GFS0P25/CENTRAL & EASTERN EUROPE/STATES ONLY/HEIGHT RH WIND Directory does not exists.
# Building new branch automatically...
# Successfully built f:Forecast Model Data/GFS0P25/CENTRAL & EASTERN EUROPE/STATES ONLY/HEIGHT RH WIND Directory.
# f:Forecast Model Data/GFS0P25/CENTRAL & EASTERN EUROPE/STATES ONLY/HEIGHT RH WIND/700 MB Directory does not exists.
# Building new branch automatically...
# Successfully built f:Forecast Model Data/GFS0P25/CENTRAL & EASTERN EUROPE/STATES ONLY/HEIGHT RH WIND/700 MB Directory.
# ...
