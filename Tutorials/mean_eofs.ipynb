# %%
'''
In this example we will create hemispheric 8-Day Mean, EOF1, EOF2, EOF1 Scores and EOF2 Scores for the GEFS 0.5x0.5 degree ensemble mean for:

1) 500mb geopotential heights
2) MSLP

We will look at both the northern and southern hemisphere

Let's start with our import!
'''
from firewxpy import ensemble_8_day_mean_eofs

# %%
# Now let's create our graphics!
ensemble_8_day_mean_eofs.plot_geopotential_height('GEFS0p50', 'N')
ensemble_8_day_mean_eofs.plot_geopotential_height('GEFS0p50', 'S')
ensemble_8_day_mean_eofs.plot_geopotential_height('GEFS0p50', 'N')
ensemble_8_day_mean_eofs.plot_geopotential_height('GEFS0p50', 'S')
# Out:
# 18z run not available yet. Now trying the 12z run.
# 12z run downloaded successfully!
# Saved Averages to f:Weather Data/Forecast Model Data/GEFS0P50/NORTHERN HEMISPHERE/STATES ONLY/GEOPOTENTIAL HEIGHT/500 MB/AVG
# Saved Averages to f:Weather Data/Forecast Model Data/GEFS0P50/NORTHERN HEMISPHERE/STATES ONLY/GEOPOTENTIAL HEIGHT/500 MB/EOF1
# Saved Averages to f:Weather Data/Forecast Model Data/GEFS0P50/NORTHERN HEMISPHERE/STATES ONLY/GEOPOTENTIAL HEIGHT/500 MB/EOF2
# Saved Averages to f:Weather Data/Forecast Model Data/GEFS0P50/NORTHERN HEMISPHERE/STATES ONLY/GEOPOTENTIAL HEIGHT/500 MB/EOF1 SCORES
# Saved Averages to f:Weather Data/Forecast Model Data/GEFS0P50/NORTHERN HEMISPHERE/STATES ONLY/GEOPOTENTIAL HEIGHT/500 MB/EOF2 SCORES
# 18z run not available yet. Now trying the 12z run.
# 12z run downloaded successfully!
# Saved Averages to f:Weather Data/Forecast Model Data/GEFS0P50/SOUTHERN HEMISPHERE/STATES ONLY/GEOPOTENTIAL HEIGHT/500 MB/AVG
# ...
