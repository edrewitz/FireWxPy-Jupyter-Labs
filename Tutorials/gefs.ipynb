# %%
'''
In this example we will plot the GEFS 0.25x0.25 degree Ensemble Mean Favorable Fire Weather Forecast
across Nebraska. The National Weather Service has issued Red Flag Warnings across Nebraska this afternoon 
and evening for 25-35 MPH winds and RH as low as 20%. 

First let's start with our import:
'''

from firewxpy import model_critical_firewx_conditions as fwf

# %%
'''
Now let's make our plots. The default wind threshold is 25 MPH so we don't need to change that. 
Given the language for relative humidity "as low as 20%" let's use 30% for our threshold to capture
areas where the sustained wind speed >= 25 MPH AND relative humidity <= 30%
'''
fwf.plot_favorable_firewx_conditions('GEFS0p25 ENS MEAN', 'ne', low_rh_threshold=30)
# Out:
# Already Satisfied: 'f:GEFS0p25 ENS MEAN Data' exists.
# Any old files (if any) in 'f:GEFS0p25 ENS MEAN Data' have been deleted.
# f:Forecast Model Data/GEFS0P25 ENS MEAN/NE/STATES & COUNTIES/FAVORABLE FIREWX RH LESS THAN 30 & SUSTAINED WINDS GREATER THAN 25 Directory does not exists.
# Building new branch automatically...
# Successfully built f:Forecast Model Data/GEFS0P25 ENS MEAN/NE/STATES & COUNTIES/FAVORABLE FIREWX RH LESS THAN 30 & SUSTAINED WINDS GREATER THAN 25 Directory.
# f:Forecast Model Data/GEFS0P25 ENS MEAN/NE/STATES & COUNTIES/FAVORABLE FIREWX RH LESS THAN 30 & SUSTAINED WINDS GREATER THAN 25/SURFACE Directory does not exists.
# Building new branch automatically...
# Successfully built f:Forecast Model Data/GEFS0P25 ENS MEAN/NE/STATES & COUNTIES/FAVORABLE FIREWX RH LESS THAN 30 & SUSTAINED WINDS GREATER THAN 25/SURFACE Directory.
# ...
