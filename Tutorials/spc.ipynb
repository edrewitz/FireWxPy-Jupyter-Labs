# %%
'''
In this example, we will make a plot of the SPC Convective Outlook and SPC Critical Fire Weather Risk Outlook for CONUS. 

Let's start with our imports
'''
from firewxpy import spc

# %%
'''
Since the convective outlook and critical fire weather risk outlooks are separate datasets, we can just download them in their 
respective functions. 
'''
spc.plot_convective_outlook()
spc.plot_critical_fire_weather_risk_outlook()
# Out:
# Retrieved ds.conhazo.bin NDFD grids.
# Saved forecast graphics to f:Weather Data/SPC Outlooks/CONVECTIVE OUTLOOK/CONUS/States & Counties
# Retrieved ds.critfireo.bin NDFD grids.
# Saved short-term forecast graphics to f:Weather Data/SPC Outlooks/CRITICAL FIRE WEATHER RISK OUTLOOK/CONUS/States & Counties
# Saved extended forecast graphics to f:Weather Data/SPC Outlooks/CRITICAL FIRE WEATHER RISK OUTLOOK/CONUS/States & Counties
