# %%
'''
In this example we will create GFS 0.25x0.25 degree 10-meter wind forecast graphics for Guyana

Start with our import!
'''
from firewxpy import model_dynamics

# %%
# Now let's make our graphics!
model_dynamics.plot_10m_winds_mslp('GFS0p25', 'Guyana')
# Out:
# 18z run not available yet. Now trying the 12z run.
# 12z run downloaded successfully!
# f:Forecast Model Data/GFS0P25/GUYANA Directory does not exists.
# Building new branches automatically...
# Successfully built f:Forecast Model Data/GFS0P25/GUYANA Branch.
# Successfully built f:Forecast Model Data/GFS0P25/GUYANA/STATES & COUNTIES Directory.
# f:Forecast Model Data/GFS0P25/GUYANA/STATES & COUNTIES/10M WIND & MSLP Directory does not exists.
# Building new branch automatically...
# Successfully built f:Forecast Model Data/GFS0P25/GUYANA/STATES & COUNTIES/10M WIND & MSLP Directory.
# f:Forecast Model Data/GFS0P25/GUYANA/STATES & COUNTIES/10M WIND & MSLP/SURFACE Directory does not exists.
# Building new branch automatically...
# Successfully built f:Forecast Model Data/GFS0P25/GUYANA/STATES & COUNTIES/10M WIND & MSLP/SURFACE Directory.
# Saved forecast graphics to f:Weather Data/Forecast Model Data/GFS0P25/GUYANA/STATES & COUNTIES/10M WIND & MSLP/SURFACE.
